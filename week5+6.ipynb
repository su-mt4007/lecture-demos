# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Rest APIs

# %%
import requests

# %%
response = requests.get("https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy", headers={
    "Authorization": "Bearer 1POdFZRZbvb...qqillRxMr2z"
})

response
# Out:
# <Response [401]>

# %% [markdown]
# # Web Scraping

# %%
from bs4 import BeautifulSoup

URL = "https://handlaprivatkund.ica.se/stores/1003422/categories"

res = requests.get(URL)

html = BeautifulSoup(res.content)

products = html.find_all("div", attrs={"class": "product-card-container"})

for product in products:
    name = product.find("h3", attrs={"data-test": "fop-title"}).get_text()
    price = product.find("span", attrs={"data-test": "fop-price"}).get_text()

    print("Name: ",name)
    print("Price: ", price)
    print("\n")
# Out:
# Name:  Mellanmjölk Lite längre hållbarhet 1,5% 1,5l ICA
# Price:  18,95 kr
#
#
# Name:  Vispgrädde 36% Längre hållbarhet 5dl ICA
# Price:  30,95 kr
#
#
# Name:  Babyplommontomater 500g Klass 1 ICA
# Price:  34,95 kr
#
#
# Name:  Läsk Pepsi Max 1,5l
# Price:  21,95 kr
#
#
# Name:  Färsk mellanmjölk 1,5% 1,5l Arla Ko®
# Price:  19,95 kr
#
#
# Name:  Gurka styck 1 pack Klass 1 ICA
# Price:  12,90 kr
#
#
# Name:  Krossade tomater 390 g ICA
# Price:  11,95 kr
#
#
# Name:  Risgröt 500g Felix
# Price:  16,95 kr
#
#
# Name:  Morötter nyskördade 1kg Klass 1 ICA
# Price:  18,95 kr
#
#
# Name:  Avfallspåse 30L 20-p ICA
# Price:  22,95 kr
#
#
# Name:  Mellanmjölkdryck 1,5% Laktosfri 1,5l Arla Ko®
# Price:  24,95 kr
#
#
# Name:  Röda babyplommontomater 250g Klass 1 ICA
# Price:  18,95 kr
#
#
# Name:  Smör Normalsaltat Svenskt 82% 500g Arla
# Price:  65,95 kr
#
#
# Name:  Havredryck iKaffe 3% 1l Oatly
# Price:  19,95 kr
#
#
# Name:  Nudlar Biff 85g Samyang
# Price:  6,95 kr
#
#
# Name:  Matlagningsgrädde 13% 5dl ICA
# Price:  25,95 kr
#
#
# Name:  Smör & Raps Normalsaltat 75% 500g Bregott®
# Price:  53,95 kr
#
#
# Name:  Standardmjölk Extra lång hållbarhet 3% 1,5l ICA
# Price:  18,95 kr
#
#
# Name:  Apelsiner Navel 1kg Klass 1 ICA
# Price:  21,95 kr
#
#
# Name:  Babytvättservetter parfymfri 72-p ICA Basic
# Price:  11,95 kr
#
#
# Name:  Laxfilé Fryst 4-p 500g Pacific brand
# Price:  107,95 kr
#
#
# Name:  Champinjon 250g Klass 1 ICA
# Price:  17,95 kr
#
#
# Name:  Majs 3-p 480g Green Giant
# Price:  29,95 kr
#
#
# Name:  Fast potatis 2kg Klass 1 ICA
# Price:  37,95 kr
#
#
# Name:  Röd spetsig paprika 200g Klass 1 ICA
# Price:  19,95 kr
#
#
# Name:  Lingongrova 500g Pågen
# Price:  24,95 kr
#
#
# Name:  Småcitrus Clemenules i nät 1kg Klass 1 ICA
# Price:  29,95 kr
#
#
# Name:  Mellanmjölkdryck Laktosfri 1,5% 1,5l ICA
# Price:  23,95 kr
#
#
# Name:  Tomatpuré 200g ICA
# Price:  17,95 kr
#
#
# Name:  Kycklingfilé Fryst 1kg Kronfågel
# Price:  97,95 kr
#
#
# Name:  Crème fraiche 32% 2dl ICA
# Price:  14,95 kr
#
#
# Name:  Läsk Cola Zero 1,5l Coca-Cola
# Price:  19,95 kr
#
#
# Name:  Saffran Malen 0,5g ICA
# Price:  17,95 kr
#
#
# Name:  Falukorv Klassikern 800g Scan
# Price:  39,95 kr
#
#
# Name:  Mjölkdryck längre hållbarhet 1,3% 1,5l Klöver®
# Price:  18,95 kr
#
#
# Name:  Risgrynsgröt 500g ICA
# Price:  13,95 kr
#
#
# Name:  Falukorv Ring 800g ICA
# Price:  35,95 kr
#
#
# Name:  Nötfärs Färsk 12% 500g ICA
# Price:  58,95 kr
#
#
# Name:  Smör- & rapsolja flytande 5dl 80% Arla Köket®
# Price:  29,95 kr
#
#
# Name:  Smör Normalsaltat 81% 500g ICA
# Price:  50,95 kr
#
#
# Name:  Jäst för matbröd 50g Kronjäst
# Price:  3,95 kr
#
#
# Name:  Fast potatis 1,2kg Klass 1 ICA
# Price:  21,95 kr
#
#
# Name:  Paprika Röd 1 pack Klass 1 ICA
# Price:  8,80 kr
#
#
# Name:  Mellanmjölkdryck Laktosfri 1,5% 1,5l Valio
# Price:  24,95 kr
#
#
# Name:  Tvättservetter Baby Oparfymerade 72-p ICA
# Price:  17,95 kr
#
#
# Name:  Läsk Julmust 1,4l Apotekarnes
# Price:  15,95 kr
#
#
# Name:  Jäst för söta degar 50g Kronjäst
# Price:  3,95 kr
#
#
# Name:  Gul lök 500g Klass 1 ICA
# Price:  11,95 kr
#
#
# Name:  Mellanmjölk 1,5% 1l ICA
# Price:  12,95 kr
#
#
# Name:  Bacon 140g Scan
# Price:  15,95 kr

# %%
URL = "https://handlaprivatkund.ica.se/stores/1003422/categories"

res = requests.get(URL)

html = BeautifulSoup(res.content)

def product_parser(product_html):
    """
    Input: Product HTML
    Output: Name, Price of product
    """
    name = product_html.find("a", attrs={"data-test": "fop-product-link"}).get_text()
    price = product_html.find("span", attrs={"data-test": "fop-price"}).get_text()

    return name, price

products = html.find_all("div", attrs={"data-test": "fop-body"})

data = []
for prod in products:
    name, price = product_parser(prod)
    data.append((name,price))

# %%
data
# Out:
# [('Mellanmjölk Lite längre hållbarhet 1,5% 1,5l ICA', '18,95\xa0kr'),
#  ('Vispgrädde 36% Längre hållbarhet 5dl ICA', '30,95\xa0kr'),
#  ('Babyplommontomater 500g Klass 1 ICA', '34,95\xa0kr'),
#  ('Läsk Pepsi Max 1,5l', '21,95\xa0kr'),
#  ('Färsk mellanmjölk 1,5% 1,5l Arla Ko®', '19,95\xa0kr'),
#  ('Gurka styck 1 pack Klass 1 ICA', '12,90\xa0kr'),
#  ('Krossade tomater 390 g ICA', '11,95\xa0kr'),
#  ('Risgröt 500g Felix', '16,95\xa0kr'),
#  ('Morötter nyskördade 1kg Klass 1 ICA', '18,95\xa0kr'),
#  ('Avfallspåse 30L 20-p ICA', '22,95\xa0kr'),
#  ('Röda babyplommontomater 250g Klass 1 ICA', '18,95\xa0kr'),
#  ('Mellanmjölkdryck 1,5% Laktosfri 1,5l Arla Ko®', '24,95\xa0kr'),
#  ('Smör Normalsaltat Svenskt 82% 500g Arla', '65,95\xa0kr'),
#  ('Havredryck iKaffe 3% 1l Oatly', '19,95\xa0kr'),
#  ('Nudlar Biff 85g Samyang', '6,95\xa0kr'),
#  ('Matlagningsgrädde 13% 5dl ICA', '25,95\xa0kr'),
#  ('Smör & Raps Normalsaltat 75% 500g Bregott®', '53,95\xa0kr'),
#  ('Standardmjölk Extra lång hållbarhet 3% 1,5l ICA', '18,95\xa0kr'),
#  ('Babytvättservetter parfymfri 72-p ICA Basic', '11,95\xa0kr'),
#  ('Champinjon 250g Klass 1 ICA', '17,95\xa0kr'),
#  ('Laxfilé Fryst 4-p 500g Pacific brand', '107,95\xa0kr'),
#  ('Röd spetsig paprika 200g Klass 1 ICA', '19,95\xa0kr'),
#  ('Majs 3-p 480g Green Giant', '29,95\xa0kr'),
#  ('Lingongrova 500g Pågen', '24,95\xa0kr'),
#  ('Apelsiner Navel 1kg Klass 1 ICA', '21,95\xa0kr'),
#  ('Småcitrus Clemenules i nät 1kg Klass 1 ICA', '29,95\xa0kr'),
#  ('Mellanmjölkdryck Laktosfri 1,5% 1,5l ICA', '23,95\xa0kr'),
#  ('Fast potatis 2kg Klass 1 ICA', '37,95\xa0kr'),
#  ('Tomatpuré 200g ICA', '17,95\xa0kr'),
#  ('Crème fraiche 32% 2dl ICA', '14,95\xa0kr'),
#  ('Läsk Cola Zero 1,5l Coca-Cola', '19,95\xa0kr'),
#  ('Mjölkdryck längre hållbarhet 1,3% 1,5l Klöver®', '18,95\xa0kr'),
#  ('Falukorv Ring 800g ICA', '35,95\xa0kr'),
#  ('Nötfärs Färsk 12% 500g ICA', '58,95\xa0kr'),
#  ('Smör- & rapsolja flytande 5dl 80% Arla Köket®', '29,95\xa0kr'),
#  ('Falukorv Klassikern 800g Scan', '39,95\xa0kr'),
#  ('Saffran Malen 0,5g ICA', '17,95\xa0kr'),
#  ('Fast potatis 1,2kg Klass 1 ICA', '21,95\xa0kr'),
#  ('Risgrynsgröt 500g ICA', '13,95\xa0kr'),
#  ('Smör Normalsaltat 81% 500g ICA', '50,95\xa0kr'),
#  ('Kycklingfilé Fryst 1kg Kronfågel', '97,95\xa0kr'),
#  ('Paprika Röd 1 pack Klass 1 ICA', '8,80\xa0kr'),
#  ('Jäst för matbröd 50g Kronjäst', '3,95\xa0kr'),
#  ('Mellanmjölkdryck Laktosfri 1,5% 1,5l Valio', '24,95\xa0kr'),
#  ('Bacon 140g Scan', '15,95\xa0kr'),
#  ('Tvättservetter Baby Oparfymerade 72-p ICA', '17,95\xa0kr'),
#  ('Gul lök 500g Klass 1 ICA', '11,95\xa0kr'),
#  ('Mellanmjölk 1,5% 1l ICA', '12,95\xa0kr'),
#  ('Feta 150g ICA', '23,95\xa0kr'),
#  ('Jäst för söta degar 50g Kronjäst', '3,95\xa0kr')]

# %% [markdown]
# # Functional Programming

# %%
base_url = "http://api.nobelprize.org/2.1"
endpoint = "/nobelprize"
query = {
 "offset": 1,
    "..": ,
}

res = requests.get(base_url + endpoint, params = query)

res
# Out:
# <Response [404]>
